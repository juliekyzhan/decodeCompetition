# %%
from pathlib import path

# %%
# 项目根目录
ROOT = Path(_file_).resolve().parents[1]

# 数据目录
DATA_DIR = ROOT / "data" / "LightGBM_raw"

# 输出目录
OUTOUT_DIR = ROOT / "output" / "LightGBM_output_latest"
TRAIN_DATA_DIR = OUTPUT_DIR / "train_data"
PRED_DIR = OUTPUT_DIR / "predictions"
